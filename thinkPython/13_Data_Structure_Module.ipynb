# %%
import book_stats as bs

# %%
text_file = 'data/poems.txt'

# %%
book_s = bs.bookStats(text_file)

# %%
bs.plot_ranks(book_s['word frequencies'])

# %%
bs.generate_text(book_s['words'])
# Out:
# 'were eager messengers of her beguiling till winning less than heaven’s may be the love and joy of love i durst not tell the rose could never hear though i most adore thee the sum of my secret i allow lest ere i come to try your simpler life will find i doubt not joys to vie with those i leave behind i have given thee beauty enough is thine as thou aslant with trim tackle and shrouding from the minster tower and then evening comes creeping up the crystal manna to freeze their tongues with tasting their hands with snowballing or rioted in a constant state of mississippi and granted tax exempt status by the copyright status of compliance to send donations or determine the status of compliance to send donations or determine the status of any kind express or implied including but not limited to warranties of merchantability or fitness for any particular paper edition most people start at our web site includes information about the mission of promoting the free distribution of electronic 
# ...

# %%
book_s['lines']
# Out:
# ['produced by larry b harrison and the online distributed',
#  'proofreading team at httpwwwpgdpnet this file was',
#  'produced from images generously made available by the',
#  'internet archive',
#  '  poems',
#  '  by',
#  '  robert bridges',
#  '  printed at the private press of',
#  '  h daniel',
#  '  fellow of worcester college',
#  '  oxford',
#  '  1884',
#  'the author of these poems is too well aware of their demerits to allow',
#  'them to be republished thus without some apology but it happens that',
#  'the printer at whose request this selection is made is willing to',
#  'take so fair a share of the blame as to make any further explanation',
#  'unnecessary',
#  '  one hundred and fifty copies printed',
#  '  this is no ——',
#  'contents',
#  '  from first series published 1873',
#  '  1 clear and gentle stream                       page 1',
#  '  2 dear lady when thou frownest                       4',
#  '  3 poor withered rose and dry                         5',
# ...
